# %%
from ultralytics import YOLO

# %%
model = YOLO('yolo11n.pt')
# Out:
# ...
# 100%|██████████| 5.35M/5.35M [00:01<00:00, 3.11MB/s]

# %%
results = model('/Users/emersonmendes/Python/Visão Computacional Guia Completo/Images/people1.jpg')
# Out:
# image 1/1 /Users/emersonmendes/Python/Visão Computacional Guia Completo/Images/people1.jpg: 448x640 8 persons, 1 cup, 1 potted plant, 2 laptops, 27.7ms
# Speed: 1.2ms preprocess, 27.7ms inference, 0.9ms postprocess per image at shape (1, 3, 448, 640)

# %%
for result in results:
    boxes = result.boxes
    result.save(filename='result.jpg')

# %%
results = model('/Users/emersonmendes/Python/Visão Computacional Guia Completo/Images/people1.jpg')
for result in results:
    boxes = result.boxes
    result.save(filename='result.jpg')

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = 'result.jpg'
image = mpimg.imread(img)
plt.imshow(image)
plt.axis('off')
plt.show()
# Out:
# image 1/1 /Users/emersonmendes/Python/Visão Computacional Guia Completo/Images/people1.jpg: 448x640 8 persons, 1 cup, 1 potted plant, 2 laptops, 30.9ms
# Speed: 1.6ms preprocess, 30.9ms inference, 0.5ms postprocess per image at shape (1, 3, 448, 640)

# %%
results = model('/Users/emersonmendes/Python/Visão Computacional Guia Completo/Images/people2.jpg')
for result in results:
    boxes = result.boxes
    result.save(filename='result.jpg')

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = 'result.jpg'
image = mpimg.imread(img)
plt.imshow(image)
plt.axis('off')
plt.show()
# Out:
# image 1/1 /Users/emersonmendes/Python/Visão Computacional Guia Completo/Images/people2.jpg: 352x640 11 persons, 35.1ms
# Speed: 1.3ms preprocess, 35.1ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
