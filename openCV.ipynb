# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
imagem = cv2.imread('/Users/emersonmendes/Python/Visão Computacional Guia Completo/Images/people1.jpg')  # Replace 'image.jpg' with your image file path

# %%
imagem.shape
# Out:
# (1280, 1920, 3)

# %%
plt.imshow(cv2.cvtColor(imagem, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %%
imagem = cv2.resize(imagem, (800, 600))

# %%
imagem.shape
# Out:
# (600, 800, 3)

# %%
imagem_cinza = plt.imshow(cv2.cvtColor(imagem, cv2.COLOR_BGR2GRAY))
plt.axis('off')
plt.show('Imagem Cinza')

# %%
detector_facial = cv2.CascadeClassifier('/Users/emersonmendes/Python/Visão Computacional Guia Completo/Cascades/haarcascade_frontalface_default.xml')

# %%
deteccoes = detector_facial.detectMultiScale(imagem)

# %%
deteccoes
# Out:
# array([[1639,  159,  141,  141],
#        [ 284,  263,  113,  113],
#        [1148,  261,  129,  129],
#        [ 928,  488,  172,  172],
#        [ 229,  509,  142,  142],
#        [ 103,  784,   56,   56],
#        [  44,  919,   30,   30]], dtype=int32)

# %%
len(deteccoes)
# Out:
# 7

# %%
for x, y, w, h in deteccoes:
    cv2.rectangle(imagem, (x, y), (x+w, y+h), (0, 255, 255), 5)
plt.imshow(cv2.cvtColor(imagem, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %%
imagem = cv2.imread('/Users/emersonmendes/Python/Visão Computacional Guia Completo/Images/people2.jpg')
imagem = cv2.resize(imagem, (800, 600))
imagem_cinza = cv2.cvtColor(imagem, cv2.COLOR_BGR2GRAY)
deteccoes = detector_facial.detectMultiScale(imagem_cinza, scaleFactor=1.25)
for x, y, w, h in deteccoes:
    cv2.rectangle(imagem, (x, y), (x+w, y+h), (0, 255, 0), 5)
plt.imshow(cv2.cvtColor(imagem, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %%
imagem = cv2.imread('/Users/emersonmendes/Python/Visão Computacional Guia Completo/Images/people3.jpg')
imagem = cv2.resize(imagem, (800, 600))
imagem_cinza = cv2.cvtColor(imagem, cv2.COLOR_BGR2GRAY)
deteccoes = detector_facial.detectMultiScale(imagem_cinza, scaleFactor=1.06)
for x, y, w, h in deteccoes:
    cv2.rectangle(imagem, (x, y), (x+w, y+h), (0, 255, 0), 5)
plt.imshow(cv2.cvtColor(imagem, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()
